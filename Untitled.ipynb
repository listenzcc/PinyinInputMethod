# %%
import os
import pandas as pd
import jieba

from tqdm.auto import tqdm
from pypinyin import pinyin, lazy_pinyin, Style

# %%
folder = 'txt'
segments = ['\r', '\n', '。', '；']

# %%
contents = []
for fname in os.listdir(folder):
    contents.append(open(os.path.join(folder, fname), 'rb').read().decode(errors='ignore'))

contents = '\n'.join(contents)
for s in segments:
    contents = contents.replace(s, '\n')
    
contents = [e.strip() for e in contents.split('\n') if e.strip()]
contents = sorted(set(contents))
contents
# Out:
# ['1903年，在日本东京',
#  '1903年，在日本东京与东京弘文学院同学合影，后排左起第一人为鲁迅',
#  '2是南京本，舌头拖出来了，不知何故',
#  '3是广州的宝经阁本，扇子破了',
#  '4是北京龙光斋本，无扇，下巴之下一条黑，我看不透它是胡子还是舌头',
#  '5是天津石印局本，也颇漂亮，然而站到第七殿泰山王的公案桌边去了：这是很特别的',
#  'TXT小说天堂  http://www.xiaoshuotxt.net，最有文艺气息的文学网站，我们提供给您的小说不求最多，但求最经典最完整.www.lzuowen.com 理想作文网',
#  'TXT小说天堂  http://www.xiaoshuotxt.net，最有文艺气息的文学网站，提供经典的文学名著、武侠小说、言情小说、人文社科类书籍在线阅读，所有TXT电子书手机免费下载阅读，我们提供给您的小说不求最多，但求最经典最完整',
#  'adeade：德语，再见的意思',
#  'ahasvar从此就歇不下，只是走，现在还在走',
#  'auntie跟你说着顽儿的',
#  'b是从南京的李光明庄刻本上取来的，图画和a相同，而题字则正相反了：天津本指为“阴无常”者，它却道是“阳无常”',
#  'california的pasadena：即加利福尼亚州的帕萨第那城',
#  'com   www.lzuowen.com',
#  'com  www.xiabook.com',
#  'com/下 书',
#  'comwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'comwwＷ、xiＡbook.cＯm',
#  'comwwＷ．lzuｏwen.com．',
#  'com下 ?^书? 网',
#  'com下 书- 网',
#  'com下$书$网',
#  'com下/书/网',
#  'com下…书 网',
#  'com下％书\u3000网',
#  'cy：英语communistyouth的缩写，即共产主义青年团',
#  'c书局：指商务印书馆',
#  'e君的发愁，或者也不为无因罢，然而俄国是不要紧的，因为他们不像我们中国，有所谓“特别国情”“特别国情”：一九一五年袁世凯阴谋恢复帝制，他的宪法顾问美国人古德诺（fjgoodnow）曾于八月十日北京《亚细亚日报》发表一篇《共和与君主论》，说中国有着自己的“特别国情”，不适宜实行民主政治，应当恢复君主政体',
#  'gorkygorky：高尔基（1868—1936），苏联无产阶级作家，社会主义现实主义文学的奠基人',
#  'g书局：指群众图书公司',
#  'hmhm：是“害马”的罗马字拼音“haima”的缩写',
#  'ks兄：',
#  'la者“的”也',
#  'ls先生：',
#  'ls启十二月二十五日',
#  'mammonmammon：这个词来源于古代西亚的阿拉米语，经过希腊语移植到近代西欧各国语言中，指财富或财神的意思，后转义为好利贪财的恶魔',
#  'nga者，“我的”或“我们的”之意也',
#  'nhatu，nhatu，nhatu－nhatu－nhatututuu！目连嗐头也冤苦不堪似的吹着',
#  'n两眼望着屋梁，似乎想些事，仍然说：',
#  'n忽然现出笑容，伸手在自己头上一摸，高声说：“我最得意的是自从第一个双十节以后，我在路上走，不再被人笑骂了',
#  'n愈说愈离奇了，但一见到我不很愿听的神情，便立刻闭了口，站起来取帽子',
#  'n显出非常得意模样，忽而又沉下脸来：',
#  'pogrom这一个字，是从po（渐渐）和gromit（摧灭）合成的，也译作犹太人虐杀',
#  'schopenhauerschopenhauer：叔本华（1788—1860），德国哲学家，唯意志论者',
#  's会馆s会馆：指绍兴县馆，在北京宣武门外',
#  's城人最不愿意有人发些没有顾忌的议论，一有，一定要暗暗地来叮他，这是向来如此的，连殳自己也知道',
#  'toutyfourmilledevie，亏曹先生体会得出',
#  'ts－cy及y－ft上十一月廿九日',
#  'ty，即“三民主义同志社”',
#  't下！书！网',
#  't下！书！网   http://www.xiaboＯk.com',
#  't下！书！网&下&书_ 网',
#  't下！书！网下 ^^书^^ 网',
#  't下！书！网下 ^书^ 网',
#  't下！书！网下{ 书 }网',
#  't下！书！网下…… 书 ……网',
#  't下！书！网下…书 网',
#  't下！书！网下！书！网',
#  't：即汤艾芜（艾芜），四川新都人',
#  'w w w. xiabook',
#  'www.56ｗen．ＣＯＭ   http://www.xiaboＯk.com',
#  'www.56ｗen．ＣＯＭ   www.lzuowen.com',
#  'www.56ｗen．ＣＯＭ  www.7wenxＵe.com',
#  'www.56ｗen．ＣＯＭwww.56wen.com',
#  'www.56ｗen．ＣＯＭ下 -书- 网',
#  'www.56ｗen．ＣＯＭ下+书+网',
#  'www.56ｗen．ＣＯＭ下{ 书 }网',
#  'www.56ｗen．ＣＯＭ下{书}网',
#  'www.56ｗen．ＣＯＭ下~书- 网',
#  'www.56ｗen．ＣＯＭ下~书~网',
#  'www.56ｗen．ＣＯＭ下——书——网',
#  'www.56ｗeｎ．ＣＯＭ   www.ｌzuoＷen．Ｃom',
#  'www.56ｗeｎ．ＣＯＭ  下 &书& 网',
#  'www.56ｗeｎ．ＣＯＭwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'www.56ｗeｎ．ＣＯＭwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'www.56ｗeｎ．ＣＯＭ下 ./书 ./网',
#  'www.56ｗeｎ．ＣＯＭ下 书- 网',
#  'www.56ｗeｎ．ＣＯＭ下$书$网',
#  'www.56ｗeｎ．ＣＯＭ下+书+网',
#  'www.7wenxue.com',
#  'www.7wenxue.com  http://www.xiaboＯk.com',
#  'www.7wenxue.com  www.7wenxue.com',
#  'www.7wenxue.com  www.7wenxＵe.com',
#  'www.7wenxue.com56wen.com',
#  'www.7wenxue.comwww.ｌＺＵＯＷＥＮ．ＣＯＭ',
#  'www.7wenxue.com下 -书- 网',
#  'www.7wenxue.com下 ?^书? 网',
#  'www.7wenxue.com下/书/网',
#  'www.7wＥnxue.com  http://www.xiaboＯk.com',
#  'www.7wＥnxue.com  www.7wenxＵe.com',
#  'www.7wＥnxue.com  下 &书& 网',
#  'www.7wＥnxue.com.  下 ?书? 网',
#  'www.7wＥnxue.com下 ./书 ./网',
#  'www.7wＥnxue.com下 /书 网',
#  'www.7wＥnxue.com下 ?^书? 网',
#  'www.7wＥnxue.com下 ^^书^^ 网',
#  'www.7wＥnxue.com下{  书 }网',
#  'www.7wＥnxue.com下…书 网',
#  'www.lzuoｗｅｎ．ｃｏｍ   www.lzuoＷen.Ｃom',
#  'www.lzuoｗｅｎ．ｃｏｍ  www.7wenxue.com',
#  'www.lzuoｗｅｎ．ｃｏｍ  www.xiabook.com',
#  'www.lzuoｗｅｎ．ｃｏｍ  下 &书& 网',
#  'www.lzuoｗｅｎ．ｃｏｍ56wen.com',
#  'www.lzuoｗｅｎ．ｃｏｍ^下 ?书? 网',
#  'www.lzuoｗｅｎ．ｃｏｍwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'www.lzuoｗｅｎ．ｃｏｍwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'www.lzuoｗｅｎ．ｃｏｍwww.ｌＺＵＯＷＥＮ．ＣＯＭ',
#  'www.lzuoｗｅｎ．ｃｏｍwwＷ、xiＡbook.cＯm',
#  'www.lzuoｗｅｎ．ｃｏｍwwｗ/５６ｗｅｎ/ｃ\u3000ｏｍ',
#  'www.lzuoｗｅｎ．ｃｏｍ下 &书& 网',
#  'www.lzuoｗｅｎ．ｃｏｍ下 ./书 ./网',
#  'www.lzuoｗｅｎ．ｃｏｍ下$书$网',
#  'www.lzuoｗｅｎ．ｃｏｍ下+书+网',
#  'www.lzuoｗｅｎ．ｃｏｍ下/书/网',
#  'www.lzuoｗｅｎ．ｃｏｍ下{  书 }网',
#  'www.lzuoｗｅｎ．ｃｏｍ下{ 书 }网',
#  'www.lzuoｗｅｎ．ｃｏｍ下——书——网',
#  'www.lzuoｗｅｎ．ｃｏｍ下…书 网',
#  'www.xia book.com   www.ｌzuoＷen．Ｃom',
#  'www.xia book.com  http://www.xiaboＯk.com',
#  'www.xia book.com  www.7wenxue.com',
#  'www.xia book.com&下&书_ 网',
#  'www.xia book.com下 //书 //网',
#  'www.xia book.com下 书',
#  'www.xia book.com下 书- 网',
#  'www.xia book.com下{书}网',
#  'www.xia book.com下\u3000书\u3000网',
#  'www.xiabook.com   http://www.xiaboＯk.com',
#  'www.xiabook.com   www.lzuowen.com',
#  'www.xiabook.com   www.lzuoＷen.Ｃom',
#  'www.xiabook.com   www.ｌzuoＷen．Ｃom',
#  'www.xiabook.com  #下!书! 网',
#  'www.xiabook.com  下 &书& 网',
#  'www.xiabook.com.  下 ?书? 网',
#  'www.xiabook.com/下 书',
#  'www.xiabook.com56wen.com',
#  'www.xiabook.comwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'www.xiabook.comwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'www.xiabook.comwwＷ．lzuｏwen.com．',
#  'www.xiabook.com下 & 书 & 网',
#  'www.xiabook.com下 &书& 网',
#  'www.xiabook.com下 -书- 网',
#  'www.xiabook.com下 //书 //网',
#  'www.xiabook.com下 ?^书? 网',
#  'www.xiabook.com下 书- 网',
#  'www.xiabook.com下$书$网',
#  'www.xiabook.com下*书+网',
#  'www.xiabook.com下+书+网',
#  'www.xiabook.com下/书/网',
#  'www.xiabook.com下~书~网',
#  'www.xiabook.com下…书 网',
#  'www.xiabook.com下\u3000书\u3000网',
#  'www.xiabook.com下％书\u3000网',
#  'www.ｌzuoＷＥＮ．ＣＯＭ   www.lzuowen.com',
#  'www.ｌzuoＷＥＮ．ＣＯＭ  http://www.xiaboＯk.com',
#  'www.ｌzuoＷＥＮ．ＣＯＭ/下 书',
#  'www.ｌzuoＷＥＮ．ＣＯＭ56wen.com',
#  'www.ｌzuoＷＥＮ．ＣＯＭwwＷ、xiＡbook.cＯm',
#  'www.ｌzuoＷＥＮ．ＣＯＭ下 & 书 & 网',
#  'www.ｌzuoＷＥＮ．ＣＯＭ下 &书& 网',
#  'www.ｌzuoＷＥＮ．ＣＯＭ下 ./书 ./网',
#  'www.ｌzuoＷＥＮ．ＣＯＭ下*书 网',
#  'www.ｌzuoＷＥＮ．ＣＯＭ下{ 书 }网',
#  'www.ｌzuoＷＥＮ．ＣＯＭ下\u3000书\u3000网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ  http://www.xiaboＯk.com',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ  www.7wenxue.com',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ  下 &书& 网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ^下 ?书? 网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭwww.ｌzuoＷeＮ．ＣＯＭ',
#  'www.ｌzuＯＷＥＮ．ＣＯＭwwＷ、xiＡbook.cＯm',
#  'www.ｌzuＯＷＥＮ．ＣＯＭwwｗ/５６ｗｅｎ/ｃ\u3000ｏｍ',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下 -书- 网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下 ./书 ./网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下 //书 //网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下 ^书^ 网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下$书$网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下*书+网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下{  书 }网',
#  'www.ｌzuＯＷＥＮ．ＣＯＭ下…… 书 ……网',
#  'www/xiabook/com  #下!书! 网',
#  'www/xiabook/comwww.56wen.com',
#  'www/xiabook/comwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'www/xiabook/com下 &书& 网',
#  'www/xiabook/com下 //书 //网',
#  'www/xiabook/com下*书+网',
#  'www、mdwenxue.com   http://www.xiaboＯk.com',
#  'www、mdwenxue.com&下&书_ 网',
#  'www、mdwenxue.comwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'www、mdwenxue.com下 -书- 网',
#  'www、mdwenxue.com下 ./书 ./网',
#  'www、mdwenxue.com下{ 书 }网',
#  'www．Ｌｚｕｏｗｅｎ．ｃｏｍ   www.lzuoＷen.Ｃom',
#  'www．Ｌｚｕｏｗｅｎ．ｃｏｍ.  下 ?书? 网',
#  'www．Ｌｚｕｏｗｅｎ．ｃｏｍwww.ｌＺＵＯＷＥＮ．ＣＯＭ',
#  'www．Ｌｚｕｏｗｅｎ．ｃｏｍ下 ./书 ./网',
#  'www．Ｌｚｕｏｗｅｎ．ｃｏｍ下*书 网',
#  'www．Ｌｚｕｏｗｅｎ．ｃｏｍ下！书！网',
#  'wwＷ、xiabook.com  www.7wenxue.com',
#  'wwＷ、xiabook.com  www.7wenxＵe.com',
#  'wwＷ、xiabook.com&下&书_ 网',
#  'wwＷ、xiabook.comwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'wwＷ、xiabook.com下 &书& 网',
#  'wwＷ、xiabook.com下 ?^书? 网',
#  'wwＷ、xiabook.com下{ 书 }网',
#  'wwＷ、xiabook.com下~书- 网',
#  'wwＷ．7wenxue.com  www.7wenxue.com',
#  'wwＷ．7wenxue.com56wen.com',
#  'wwＷ．7wenxue.comwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'wwＷ．7wenxue.comwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'wwＷ．7wenxue.comwwＷ、xiＡbook.cＯm',
#  'wwＷ．7wenxue.com下 /书 网',
#  'wwＷ．7wenxue.com下*书+网',
#  'wwＷ．7wenxue.com下——书——网',
#  'wwＷ．7wenxue.com下\u3000书\u3000网',
#  'wwＷ．lzuｏwen.com  #下!书! 网',
#  'wwＷ．lzuｏwen.comwww.56wen.com',
#  'wwＷ．lzuｏwen.comwww.ｌzuoＷeＮ．ＣＯＭ',
#  'wwＷ．lzuｏwen.comwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'wwＷ．lzuｏwen.comwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'wwＷ．lzuｏwen.comwwＷ．lzuｏwen.com．',
#  'wwＷ．lzuｏwen.com下{书}网',
#  'wwＷ．lzuｏwen.com下％书\u3000网',
#  'wwＷ．ｘｉａｂｏｏｋ.com  #下!书! 网',
#  'wwＷ．ｘｉａｂｏｏｋ.com  下 &书& 网',
#  'wwＷ．ｘｉａｂｏｏｋ.com&下&书_ 网',
#  'wwＷ．ｘｉａｂｏｏｋ.com下 & 书 & 网',
#  'wwＷ．ｘｉａｂｏｏｋ.com下 /书 网',
#  'wwＷ．ｘｉａｂｏｏｋ.com下 ?^书? 网',
#  'wwＷ．ｘｉａｂｏｏｋ.com下/书/网',
#  'wＷw',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍ   http://www.xiaboＯk.com',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍ  www.7wenxＵe.com',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍ下 ./书 ./网',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍ下 ^^书^^ 网',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍ下$书$网',
#  'wＷw：xiaｂｏｏｋ．ｃｏｍ下*书 网',
#  'xiabｏok.com  www.7wenxＵe.com',
#  'xiabｏok.com  下 &书& 网',
#  'xiabｏok.comwww.ｌzuoＷＥＮ．ＣＯＭ',
#  'xiabｏok.comwww.ｌzＵＯＷＥＮ．ＣＯＭ',
#  'xiabｏok.comwwｗ/５６ｗｅｎ/ｃ\u3000ｏｍ',
#  'xiabｏok.com下 &书& 网',
#  'xiabｏok.com下$书$网',
#  'xiabｏok.com下*书 网',
#  'xiabｏok.com下/书/网',
#  'xiabｏok.com下~书- 网',
#  'y及ty：即杨子青（沙汀），四川安县人',
#  '——',
#  '——“学匪”派考古学之一',
#  '——“我决不至于昧了良心',
#  '——一九三二年十一月二十二日',
#  '——一九二七年二月十六日',
#  '——一九二三年十二月二十六日在',
#  '——一九二九年五月二十二日',
#  '——一九二六年在厦门',
#  '——一九二六年在厦门大学',
#  '——一九二四年一月十七日在',
#  '——一望全是粉墙，',
#  '——一阵脚步声响，一眨眼，已经拥过了一大簇人',
#  '——上海去了',
#  '——不多工夫，已经全在肚里了，却全忘了什么味',
#  '——不过如此，但也为我所十分甘愿的',
#  '——不过当作别人的一点谈助，并且借此知道一点希腊神话而已，于赵先生的“与其信而不顺，不如顺而不信”的格言，却还是毫无损害的',
#  '——亲戚本家早不来了',
#  '——人会没有声音的么？没有，可以说，是死了',
#  '——什么谓之“有益”，非在本问题范围之内，这里且不论',
#  '——他命令康儿和两个弟妹进学校去了',
#  '——他简直称大报的记者为“蛆虫”——来，真是“小巫见大巫”，使我自惭究竟不及白人之毒辣勇猛',
#  '——他那时是委员——接着演说，说这是我太谦虚，就我过去的事实看来，确是一个战斗者，革命者',
#  '——休息一会，就没有什么了',
#  '——但总可以说些较真的话，发些较真的声音',
#  '——但我想，我们大概究竟不是一路的',
#  '——但是我也就送她了，母亲只要说阿顺见了喜欢的了不得就是',
#  '——但是我们就谈谈罢',
#  '——但是，我不知道',
#  '——但是，此刻太平湖饭店之宴已近阑珊，大家都已经吃到冰其淋，在那里“冷一冷”了罢……',
#  '——但蛇自己不肯被打，也自然不消说得',
#  '——但这也不能去怪谁，只能怪顺姑自己没有这一份好福气',
#  '——但这也许是后来的回忆的感觉，那时其实是还没有如此分明的',
#  '——但这先生自然是西医',
#  '——但这是我个人的推测',
#  '——作者原注',
#  '——你如果真在这里，听到我的话，——便教这乌鸦飞上你的坟顶，给我看罢',
#  '——你想，那多么可叹？……”',
#  '——你那，什么呢，你的朋友罢，子君，你可知道，她死了',
#  '——其实这样的年纪，讨饭是很不相宜的了，可是她还讨饭',
#  '——农民和工人',
#  '——分明有一圈红白的花，围着那尖圆的坟顶',
#  '——创作要怎样才会好？',
#  '——创造社有革命文学，时行的文学，不过附和的',
#  '——反对者承认“革命文学”和“平民文学”“贵族文学”同为文学上一种名词，与文学革命无关，而怀疑其像煞有介事的神圣不可侵犯',
#  '——可是又无他们的彻底，而把“文学革命”与“革命文学”并为一谈',
#  '——否则，便要不肯将余屋租给我似的单身人',
#  '——呵！回来还是我的家',
#  '——和一个六七十岁的老的，白头发，眼睛是瞎的，坐在布店的檐下求乞',
#  '——哦，有了，他们都爱看《理想之良人》',
#  '——唉唉，她真是交了好运了',
#  '——唔，不对',
#  '——四月八日在黄埔军官学校讲',
#  '——大踏步走了过来',
#  '——她后来还是这样，直到我毕业，有了事做，生活比先前安定些',
#  '——好极好极',
#  '——如果当真是一片沙漠，这虽然荒漠一点也还静肃',
#  '——子君，你怎么今天这样儿了？”我忍不住问',
#  '——小衫，露着胖得拥成折叠的胸肚，使汗珠雍容地越过了折叠往下流',
#  '——怀疑他们所谓革命文学的，是九五日报社',
#  '——我其实也并不比我所怕见的神经过敏而自尊的文学青年高明',
#  '——我想，他们说的也许是‘阿尔特肤尔’“阿尔特肤尔”英语oldfool的音译，直意为“老傻瓜”',
#  '——我想，熟门熟路，比生手实在好得多……',
#  '——我早经说过：她是粗笨女人',
#  '——我每月有二十元，也不大能够敷衍',
#  '——我突然想到她的死，然而立刻自责，忏悔了',
#  '——我说不清',
#  '——或者不如住在客店里，什么都包给他们，一个人干干……”他听得呜咽声高了起来，也就站了起来，钻过门幕，想着，“马克思在儿女的啼哭声中还会做《资本论》，所以他是伟人，……”走出外间，开了风门，闻得一阵煤油气',
#  '——或者不必定用留学生，就在国内受了高等教育的也可以',
#  '——拟古的新打油诗拟古的新打油诗：拟古，这里是模拟东汉文学家、天文学家张衡的《四愁诗》的格式',
#  '——拟许钦文',
#  '——日本那一面，好像是喜欢称为“事变”似的——的火线下，而且自由早被剥夺自由早被剥夺：指作者被通缉的事情',
#  '——涓生的手记',
#  '——然而也未必，……谁来管这等事……',
#  '——然而只有一件外套，其中无物',
#  '——然而我现在就是这样',
#  '——王九妈，你有年纪，见的多，不如请你老法眼法眼：佛家用语',
#  '——瑜儿，可怜他们坑了你，他们将来总有报应，天都知道',
#  '——的骁将，昼夜奔走，向国务院呼号，向财政部坐讨，一旦到手，对于没有一同去索的人的无功受禄，心有不甘，用此给吃一点小苦头的',
#  '——监狱里的生活比这里好得多',
#  '——看他意思是正要活',
#  '——真，自然是不容易的',
#  '——第一要算我们栓叔运气',
#  '——纪念几个死者和生者和未生者',
#  '——终于，则甚至闪出了惟本身目前的刹那间为惟一的现实一流的阴影',
#  '——而我，……这算是什么？……”他想到这里，忽然从床上跳起来了',
#  '——自然原也没有知道得很清楚',
#  '——自然，这样一移，的确比较的好看些，然而解剖图不是美术，实物是那么样的，我们没法改换它',
#  '——致《文学月报》编辑的一封信',
#  '——荷生就在他身边，他又举起了手掌……',
#  '——荷生满脸是血，哭着进来了',
#  '——菜？十个油豆腐，辣酱要多！”',
#  '——虽说英国正史上并无“博徒列传”，而文豪迭更司迭更司（1812—1870）：通译狄更斯，英国小说家',
#  '——譬如想有乔木，想看好花，一定要有好土',
#  '——还没有见他，',
#  '——这……”',
#  '——这可以放心，她必不至于捧着白菜的',
#  '——这地方有谁来呢？孩子不会来玩',
#  '——这声音是怎么念的？”他指着前面的“鬼子”字，问',
#  '——这是怎么一回事呢？”她想了又想，忽又流下泪来，大声说道，“瑜儿，他们都冤枉了你，你还是忘不了，伤心不过，今天特意显点灵，要我知道么？”他四面一看，只见一只乌鸦，站在一株没有叶的树上，便接着说，“我知道了',
#  '——这真是恶鬼的眼泪',
#  '——锈铁链子系着',
#  '——闹是谁也总要闹一闹的',
#  '——阿阿，你这样的看我，你怪我何以和先前太不相同了么？是的，我也还记得我们同到城隍庙里去拔掉神像的胡子的时候，连日议论些改革中国的方法以至于打起来的时候',
#  '——靖甫也正是这样地躺着，但却是一个死尸',
#  '——鸡也叫了',
#  '‘一到明天，我必须去献给大王',
#  '‘上那西山呀采它的薇菜，',
#  '‘二十五斤’？不管他',
#  '‘你的大姊呢？’他立刻瞪起眼睛，连声问我寻她什么事，而且恶狠狠的似乎就要扑过来，咬我',
#  '‘写长信，就是反革命的！’”我一面想',
#  '‘出门不管’，两位小姐的安全要你们负责了',
#  '‘千方百计’那四个字，我到死都忘不了的',
#  '‘反革命’太重，应该说是‘不革命’的',
#  '‘咯支咯支’，简直是不要脸！”',
#  '‘国立三闾大学’？这名字生得很我从来没听见过',
#  '‘女孩子，念什么书？’九公公先前这样说，反对女学的时候，我还攻击他呢',
#  '‘斯人也而有斯姓也……那一定是上帝的审判了',
#  '‘无声的呐喊’五个字真把夏天蠢动怒发的生机全传达出来了',
#  '‘莫遣佳期更后期’，这话很有道理',
#  '‘赠人以车，不如赠人以言’',
#  '‘这是雄剑',
#  '‘醉倚青鸾上碧霄’，多么超脱……那邓孝翁叩求了五回，这才赐了一首五绝……‘红袖拂天河，莫道……’蕊珠仙子说……础翁还是第一回……这就是本校的植物园！”',
#  '‘阅世长松下，读书秋树根’',
#  '‘麻雀虽小，五脏俱全’',
#  '’',
#  '’‘奇怪呀，’她的丈夫说',
#  '’”',
#  '’”丛边作道场',
#  '’”似的脸来',
#  '’”增惆怅，插竹编篱好护持',
#  '’”意思是冷落的职位，也泛指受人冷遇、无事可做',
#  '’”李先生本来像冬蛰的冷血动物，给顾先生当众恭维得春气入身，蠕蠕欲活，居然赏脸一笑道：“做大事业的人都相信命运的',
#  '’”治世的时候，人民被刮得衣裤全无，只用一片瓦掩着下部，然而还要追捐，除被打得麂一般叫之外，并无贰话',
#  '’”盈卮',
#  '’”阿堵，当时俗语：这个',
#  '’”（按：周作人之妻为日本人',
#  '’”，非拖开不可',
#  '’……”他们俩虽然都沦落，但其时却没有什么大悲哀，所以还都笑',
#  '’……遂得兼养儿',
#  '’一面就慢慢的伸开臂膊，要去拿石片',
#  '’不可以说的，要说‘大娘’',
#  '’于是乃以药涂屋柱，饮牛马六畜',
#  '’于是饿死',
#  '’他于是得到一番感谢',
#  '’他于是得到一顿大家合力的痛打',
#  '’他于是收回几句恭维',
#  '’他交运之后，人来人往，我把正屋也让给他住了，自己便搬在这厢房里',
#  '’他们不说什么，撅着嘴唇走出房去，然而终于剪掉了',
#  '’他写这种信，是地道中国文化的表现',
#  '’他听错了，以为我说‘鸡在这水里洗过脚’，还跟我开玩笑说什么‘饶你奸似鬼，喝了洗脚水’——”大家都笑，汪先生欣然领略自己的妙语——“我叫她来问，她直赖',
#  '’他悄悄地对我说',
#  '’他没有话讲，唉，他们没有话讲',
#  '’他说，‘你收着',
#  '’以其子妻之',
#  '’你想，这……”',
#  '’原文字句记不得了，可是意思决不会开错',
#  '’因起舞',
#  '’妻子恋家不忍去',
#  '’当三个有闲之暇，也活剥一首来吊卢骚',
#  '’我既非秀才，又要周考真是为难……”然而终于又一章',
#  '’我明天去找她',
#  '’我真不懂得我明明有着一个祖母，怎么又会有什么‘自己的祖母’来',
#  '’我说，‘不行！’‘有辫子好呢，没有辫子好呢？’‘没有辫子好……’‘你怎么说不行呢？’‘犯不上，你们还是不剪上算，——等一等罢',
#  '’昌期，字鸣凤',
#  '’易泄痢，黔娄辄取尝之”',
#  '’有位我们系里的同事，也是个副教授，把它改了一句：‘替如夫人争气',
#  '’这是什么意思？你也就是他们这一党：你知道的',
#  '’（齐）威王勃然怒曰：‘叱嗟，而（尔）母碑也！’”“赘阉遗丑”：见陈琳《为袁绍檄豫州（刘备）文》：“操赘阉遗丑，本无懿德',
#  '“akon，agon！”有些东西向伊说',
#  '“alayoop”：吆喝的声音，格罗泼以此作为画册的名字',
#  '“ch……正的，h……副的',
#  '“measles……”普悌思低声自言自语似的说',
#  '“nga！nga！”“nga！nga！”以及下文的“akon！agon！”“uvu，ahaha！”都是用拉丁字母拼写的象声调',
#  '“nga！nga！”译音似“嗯啊！嗯啊！”“akon！agon！”译音似“阿空，阿公！”“uvu，ahaha！”译音似“呜呜，啊哈哈！”那些小东西可是叫起来了',
#  '“uvu，ahaha！”他们笑了',
#  '“——他在剑桥念文学，是位新诗人，新近回国',
#  '“——我本来英文是不行的，这次教英文一半也因为刘先生的命令，讲错当然免不了，只希望刘先生当面教正',
#  '“‘comein，please，mydear’这一行英文的意思是：“请进来，我亲爱的',
#  '“‘mydear，please’',
#  '“‘ohno，pleaseyou！’这三行英文的意思是：“我亲爱的，请',
#  '“‘pleaseyoueatfirst，mydear’',
#  '“‘你……’我很骇异，猜不透他的意思，不知怎么说的好',
#  '“‘你不要悲哀',
#  '“‘你只要看这几天的景象，就明白无论是谁，都知道剑已炼就的了',
#  '“‘君子动口不动手’！”阿q歪着头说',
#  '“‘唉！你怎么知道呢！’他说，‘大王是向来善于猜疑，又极残忍的',
#  '“‘啊！祖国！’',
#  '“‘天不打吃饭人’，你今天怎么尽闹脾气，连吃饭时候也是打鸡骂狗的',
#  '“‘尔础高老夫子’？谁呢？你么？你改了名字了么？”黄三一看完，就性急地问',
#  '“‘恶毒妇’是‘很凶的女人’，我倒不懂，得来请教你？——这不是中国话，是鬼子话，我对你说',
#  '“‘恶毒妇’？……那是，‘很凶的女人’罢？……”',
#  '“……ch……h……所组织之木刻研究会，系受共党指挥，研究普罗艺术之团体也',
#  '“……”',
#  '“……他们两人正在用午餐，”他想，“桌上铺了雪白的布',
#  '“……你打了丧钟！……”远远地还送来叫骂',
#  '“……做不做全由自己的便',
#  '“……况迩来世风日下，沿习浇漓，不知孝出天性自然，反以孝作另成一事',
#  '“……北京是明清的帝都，上海乃各国之租界，帝都多官，租界多商，所以文人之在京者近官，没海者近商，近官者在使官得名，近商者在使商获利，而自己亦赖以糊口',
#  '“……南苑的人民，没有收成，没有粮食，没有工做，就让有这两亩田又有什么用处？……一遇到些少的扰乱，就把整千的人投到灾民的队伍里去',
#  '“……和尚动得……女人，女人！……女人！”他又想',
#  '“……坊间所刻《二十四孝》，善矣',
#  '“……我们中几个很不以他这句话为然，我们以为我们还有许多可骂的地方，我们正想骂骂自己，难道鲁迅先生竟看不出我们的缺点么？……”',
#  '“……所以主人的书房门永远是关起来的',
#  '“……是日执行之后，因马（淑纯，十六岁',
#  '“……本书的第五编即女子教育，他的主张非但不彻底，而且不承认女子的人格，与前四编的尊重人类相矛盾',
#  '“……正当的女子教育应该是使女子成为完全的女子',
#  '“……死了的曹娥，和她父亲的尸体，最初是面对面抱着浮上来的',
#  '“……第用学生自治会名义，指挥讲师职员，召集校务维持讨论会，……本校素遵部章，无此学制，亦无此办法，根本上不能成立',
#  '“……考铁长女诗，乃吴人范昌期《题老妓卷》作也',
#  '“……莱子又有弄雏娱亲之事：尝弄雏于双亲之侧，欲亲之喜',
#  '“……赐了一个荸荠……',
#  '“……迨五月七日校内讲演时，学生劝校长杨荫榆先生退席后，杨先生乃于饭馆召集校员若干燕饮，继即以评议会名义，将学生自治会职员六人揭示开除，由是全校哗然，有坚拒杨先生长校之事变',
#  '“《八月的乡村》整个地说，他是一首史诗，可是里面有些还不真实，像人民革命军进攻了一个乡村以后的情况就不够真实',
#  '“《拓荒者》说我是资本家的走狗，是哪一个资本家，还是所有的资本家？我还不知道我的主子是谁，我若知道，我一定要带着几份杂志去到主子面前表功，或者还许得到几个金镑或卢布的赏赉呢',
#  '“一个说：‘这孩子将来是要死的',
#  '“一个说：‘这孩子将来要做官的',
#  '“一个说：‘这孩子将来要发财的',
#  '“一人一个，都一样的',
#  '“一代不如一代！”',
#  '“一代不如一代！”九斤老太说',
#  '“一代不如一代，——”九斤老太正在不平，趁这机会，便对赵七爷说，“现在的长毛，只是剪人家的辫子，僧不僧，道不道的',
#  '“一切都已完结，一切都已完结！可怜的魔鬼们将那好的地狱失掉了！”他悲愤地说，于是坐下，讲给我一个他所知道的故事——',
#  '“一大一小？这是谁呢？”我有些诧异',
#  '“一定是了！”羿在膝上一拍，即刻站起，走出屋外去，回头问着女辛道，“那边？”',
#  '“一家人家生了一个男孩，合家高兴透顶了',
#  '“一总总得一百八十块钱才够开销……发了么？”伊并不对着他看的说',
#  '“一斤绍酒',
#  '“一方面是庄严的工作，另一方面却是荒淫与无耻！”',
#  '“一直到了济南，”他向窗外看了一回，转身喝干一杯酒，又吸几口烟，接着说',
#  '“一直挨到现在，趁着年假的闲空，我才得回南给他来迁葬',
#  '“一路走去，一路便是笑骂的声音，有的还跟在后面骂：‘这冒失鬼！’‘假洋鬼子！’',
#  '“丁牺牲了性命，乃是闹得一塌糊涂，活不下去了的缘故',
#  '“七大人是知书识理，顶明白的',
#  '“七大人看看，”默默地站在她后面的“小畜生”忽然说话了',
#  '“七大人？”八三的眼睛睁大了',
#  '“七姬墓志”：元末明初张士诚的女婿潘元绍被徐达打败，怕他的七个小妾被夺，即逼令她们一齐自缢，七人死后合葬于苏州，明代张羽为作墓志，称为《七姬权厝志》',
#  '“万岁！”他们都拍掌欢呼起来',
#  '“三弟，有什么捞儿捞儿：也作落儿',
#  '“上了街？……”她一面看，一面问',
#  '“上半天，”他放松了胡子，慢慢地说，“西头，老富的中风，他的儿子，就说是：因为，社神不安，之故',
#  '“上城去了！”',
#  '“上海的书铺子？买稿要一个一个的算字，空格不算数',
#  '“上真上真：道教称修炼得道的人为真人',
#  '“下等人”还未暴发之先，自然大抵有许多“他妈的”在嘴上，但一遇机会，偶窃一位，略识几字，便即文雅起来：雅号也有了',
#  '“不',
#  '“不上城，”木公公有些颓唐似的，但因为紫糖色脸上原有许多皱纹，所以倒也看不出什么大变化，“就是到庞庄去走一遭',
#  '“不会有他罢',
#  '“不像我们乡下人',
#  '“不准我造反，只准你造反？妈妈的假洋鬼子，——好，你造反！造反是杀头的罪名呵，我总要告一状，看你抓进县里去杀头，——满门抄斩，——嚓！嚓！”',
#  '“不几天，这位监督却自己被人剪去辫子逃走了',
#  '“不可与言而与之言”，即是“知其不可为而为之”，一定要有这种人，世界才不寂寞',
#  '“不喝了，不喝了……”伯夷和叔齐且走且说，一面不住的点着头',
#  '“不妨事么？他……”',
#  '“不对，不对，不是这个',
#  '“不对？他们何以竟吃？！”',
#  '“不慌！只烧死了自己，宝贝可没有烧哩',
#  '“不成',
#  '“不成！你没法开！”',
#  '“不抵抗”在字面上已经说得明明白白',
#  '“不料竟全改了文王的规矩……你瞧罢，不但不孝，也不仁……这样看来，这里的饭是吃不得了',
#  '“不是',
#  '“不是等不迭了，自己上饭馆去了么？”',
#  '“不是股本是什么？”我就不再说下去了，这一点世故是早已知道的，倘我再说出连累我们的话来，他就会面斥我太爱惜不值钱的生命，不肯为社会牺牲，或者明天在报上就可以看见我怎样怕死发抖的记载',
#  '“不是这么说',
#  '“不是那个',
#  '“不相信”就是“愚民”的远害的堑壕，也是使他们成为散沙的毒素',
#  '“不相干，”他又回过头来想，“什么‘二十五斤’？——他们是优美高尚，很爱文艺的',
#  '“不知道是什么病？不要紧罢？”靖甫问，眼里发出忧疑的光，显系他自己也觉得不寻常了',
#  '“不知道！”他似乎很不高兴，脸上还有怒色了',
#  '“不知道？你不要骗我！这不是露西亚露西亚：俄罗斯的日文译名',
#  '“不行不行，那不行！二十五斤！”',
#  '“不要再看了',
#  '“不要多心，薇翁',
#  '“不要强辩了，你总是‘执迷不悟’！我们很知道你在拘留所里的生活很苦',
#  '“不要紧的！”道统大声说',
#  '“不要紧的，……伤风罢了',
#  '“不见得',
#  '“不认识了么？我还抱过你咧！”',
#  '“不过公输般已经给我在造云梯，总得去攻的了',
#  '“不过成败也还是说不定的',
#  '“不错',
#  '“不错！”墨子说',
#  '“不错，”墨子说，“不过他听不听我，还是料不定的',
#  '“不！”他不放手，“我来办',
#  '“不，”老子摆一摆手，“我们还是道不同',
#  '“不，不',
#  '“不，不！不忙，不忙！兄弟以为振兴女学是顺应世界的潮流，但一不得当，即易流于偏，所以天曹不喜，也许不过是防微杜渐的意思',
#  '“不，他们自己咬',
#  '“不，开头也常常看错',
#  '“不，我想出去，换换新鲜空气……”',
#  '“不，我知道，”孙小姐温柔而固执着，“这是你提醒赵先生的',
#  '“不，打到你府上去的',
#  '“不，简直是拉来的夫子',
#  '“不，苏小姐，不，我不敢见你——”不能再遮饰了，低声道：“我另有——”怎么说呢？糟透了！也许同事们全在偷听——“我另外有——有个人',
#  '“不，那一包',
#  '“且介”即取“租界”二字的一半',
#  '“且住！”',
#  '“且慢！我们再谈谈……”他在后面大声挽留',
#  '“且慢，”羿说着，想了一想，“那倒不忙',
#  '“世故”似乎也像“革命之不可不革，而亦不可太革”一样，不可不通，而亦不可太通的',
#  '“世故”深到不自觉其“深于世故”，这才真是“深于世故”的了',
#  '“世道浇漓，人心日下，国将不国”这一类话，本是中国历来的叹声',
#  '“丙讲革命是为的要图利：不为图利，为什么要讲革命？我亲眼看见他三千七百九十一箱半的现金抬进门',
#  '“东坡”两个字给鲍小姐南洋口音念得好像法国话里的“坟墓”（tombeau）',
#  '“东城的美亚药房！一定得到那里去',
#  '“东西，……直走进去打开箱子来：元宝，洋钱，洋纱衫，……秀才娘子的一张宁式床宁式床：浙江宁波一带一种比较讲究的床',
#  '“两个穷光蛋，真的什么也没有！”他满脸显出失望的颜色，转过头去，对小穷奇说',
#  '“中国为什么没有伟大文学产生？”我们听过许多指导者的教训了，但可惜他们独独忘却了一方面的对于作者和作品的摧残',
#  '“中国什么都黑暗，谁也不行，但没有事的时候是看不出来的',
#  '“丸泥”，见《后汉书·隗嚣传》中王元对隗嚣说的话：“元请以一丸泥为大王东封函谷关',
#  '“为了乐器动兵，是不合先王之道的',
#  '“为了出关，我看这也敷衍得过去了',
#  '“为什么不告诉她？——不，不，我刚才发脾气，对她讲过今天什么地方都不去的',
#  '“为什么呀？怕他没有死吗？”别一人问道',
#  '“为什么呢？”我无端地这样问，立刻连自己也觉得可笑了',
#  '“为什么？”',
#  '“为医学而教的解剖学之类，怕于生物学也没有什么大帮助',
#  '“为幼稚者”仿佛不大能够“体贴尊长之心”似的，很诉了许多苦，然而我们有什么权利来干预“家庭”里的事呢？而况太平湖饭店里又要“解决种种重要问题”了！但是我也说明了几句我所以来校的理由，并要求学校当局今天缩头缩脑办法的解答',
#  '“义哥是一手好拳棒，这两下，一定够他受用了',
#  '“义士呢',
#  '“之后就去找纣王的两个小老婆',
#  '“乐户”：封建时代罪人妻女被编入乐籍者，其名称最早见于《魏书·刑罚志》',
#  '“九·一八”事变后曾来过中国，著有《秘密的中国》等',
#  '“九·一八”事变后，全国学生奋起抗议蒋介石的不抵抗政策',
#  '“九·一八”事变后，国联袒护日本帝国主义对中国的侵略，九月二十二日，蒋介石在南京市国民党党员大会上宣称：“此刻必须上下一致，先以公理对强权，以和平对野蛮，忍辱含愤，暂取逆来顺受态度，以待国际公理之判决',
#  '“九·一八”事变时，张学良奉蒋介石“绝对抱不抵抗主义”的命令，放弃东北',
#  '“九世之仇，百年之友，均在觉悟不觉悟之关系头上，”——“日本只有一个方法可以征服中国，即悬崖勒马，彻底停止侵略中国，反过来征服中国民族的心',
#  '“九十元！你就是打官司打到皇帝伯伯跟前，也没有这么便宜',
#  '“也不单为了乐器',
#  '“也已经募集了一些麻，灰，铁',
#  '“也没人说',
#  '“也终于在这里！”',
#  '“也许人家讲你像狐狸，吃不到葡萄就说葡萄酸',
#  '“也许你表姐有她的心思，遣将不如激将，非有大敌当前，赵先生的本领不肯显出来',
#  '“也许如此罢',
#  '“也许明天就收到一个电报，拆开来一看，是鲁迅来叫我的',
#  '“也许有罢，——我想',
#  '“也许，可是并不在一切陌生的女人前面',
#  '“也还是为了无聊的事',
#  '“也还是为了爱姑的事么？”好一会，八三质问了',
#  '“予生也晚”，赶不上周朝，未为大夫，也没有做士，本可以放笔直干的，然而终于改头换面，从“国骂”上削去一个动词和一个名词，又改对称为第三人称者，恐怕还因为到底未曾拉车，因而也就不免“有点贵族气味”之故',
#  '“予预计于旧历正月间，当能与君在天津晤谈',
#  '“二十三斤半，……”他觉得劈柴就要向床下“川流不息”的进来，头里面又有些桠桠叉叉了，便急忙起立，走向门口去想关门',
#  '“二十四史”而多至二十四，就是可悲的铁证',
#  '“于我来了一道光”，从此以后，我自己觉得颇聪明，近于老官僚了',
#  '“于是一碗‘龙虎斗’摆在桌子中央了，他们两人同时捏起筷子，指着碗沿，笑迷迷的你看我，我看你……',
#  '“于是他们同时伸下筷子去，同时夹出一块蛇肉来，——不不，蛇肉究竟太奇怪，还不如说是鳝鱼罢',
#  '“亏得我会赚几个钱，否则我真给你欺负死了',
#  '“五四”新文化以后曾标点《红楼梦》《水浒传》等小说，由上海亚东图书馆出版',
#  '“五四”时代，陈大齐陈大齐：字百年，浙江海盐人，心理学家',
#  '“五四”运动前后，中国的无政府主义者曾组织“民声社”“进化社”等小团体，出版刊物和小册子宣扬这种思想',
#  '“亲领”问题的历史，是起源颇古的，中华民国十一年，就因此引起过方玄绰方玄绰：作者一九二二年所作短篇小说《端午节》中的人物，并非真有其人',
#  '“亲领这一层也已经取消了，听说仍旧由会计科分送',
#  '“亲领？……”伊惴惴的问',
#  '“人之初，性本善”么？这并非现在要加研究的问题',
#  '“人心不古，……”',
#  '“人心不古，康回实有豕心，觑天位，我后躬行天讨，战于郊，天实佑德，我师攻战无敌，殛康回于不周之山',
#  '“人来呀！强盗在毁咱们的屋子了！快来呀！迟一点可要打出窟窿来了！……”',
#  '“人生的变化多么迅速呵！这半年来，我几乎求乞了，实际，也可以算得已经求乞',
#  '“人类于是完全掌握了地狱的大威权，那威棱且在魔鬼以上',
#  '“人类便应声而起，仗义执言，与魔鬼战斗',
#  '“人言可畏”是电影明星阮玲玉自杀之后，发见于她的遗书中的话',
#  '“人都到哪里去了？！”',
#  '“什么呢？……不要嚷……不……”他低低地说，又较急地喘着气，好一会，这才复了原状，平静下去了',
#  '“什么时候，起的？”普悌思两手插在裤侧的袋子里，凝视着病人的脸，慢慢地问',
#  '“什么时候？——昨天夜里，或者就是今天罢',
#  '“什么时症呢？”沛君吃惊了，赶忙地问',
#  '“什么样子的？”',
#  '“什么法呢？我‘文不像誊录生，武不像救火兵’，别的做什么？”',
#  '“什么老法子？”庄七光诧异地问',
#  '“什么花？”',
#  '“什么菜？菜倒不妨奇特点',
#  '“什么话？那有什么相干？我因为记起了你没有肥皂……”',
#  '“什么！？”我气愤了，觉得这是一个极端的侮辱',
#  '“什么？”',
#  '“什么？”他以为她来搅扰了他的创作，颇有些愤怒了',
#  '“什么？”伊向来没有听过这类话，非常诧异了',
#  '“什么？”伊大约仍然没有懂',
#  '“什么？”刘东方跳起来，“谁说的？”孙小姐脸上的表情更是包罗万象，假装看书也忘掉了',
#  '“什么？”四铭正想发话，但一回头，看见她陷下的两颊已经鼓起，而且很变了颜色，三角形的眼里也发着可怕的光，便赶紧改口说，“我也没有闹什么脾气，我不过教学程应该懂事些',
#  '“什么？”她连看也不看我',
#  '“什么？”她随口的问，并不惊奇',
#  '“什么？”阔亭疑心自己没有听清楚',
#  '“什么？”阿q不平起来了',
#  '“什么？”靖甫睁开了眼睛，问',
#  '“什么？……”',
#  '“什么？……”阿q诧异了',
#  '“什么？副教授里还分等么？”鸿渐大有英国约翰生博士不屑分别臭虫和跳虱的等级的意思',
#  '“什么？太太到姚家去了么？”羿还呆坐在马上，问',
#  '“什么？我没听清楚',
#  '“什么？！”王说',
#  '“仇人相见，分外眼明”，阿q便迎上去，小d也站住了',
#  '“仇猫”的话柄，也从此传扬开来',
#  '“今天天气……哈哈哈！”虽然有些普遍，但能否永久，却很可疑，而且也不大像文学',
#  '“今天子君的父亲来到这里，将她接回去了',
#  '“今天怎样？”他立刻问',
#  '“今天总还要算运气的，”羿也高兴起来，“居然猎到一只麻雀',
#  '“今天是第一天，就是这样罢……',
#  '“今天的报上就说，现在时症流行……”',
#  '“今天的运气仍旧不见佳，还是只有乌鸦……',
#  '“今年你几岁？”——第二句',
#  '“仍然留起，嫁给人家做媳妇去：忘却了一切还是幸福，倘使伊记着些平等自由的话，便要苦痛一生世！',
#  '“从来如此，便对么？”',
#  '“从第八章《东晋之兴亡》起',
#  '“他不咬人么？”',
#  '“他不是先就发过一回疯么，和现在一模一样',
#  '“他不是发了疯么？你还没有知道？”方头带些藐视的神气说',
#  '“他不是长久没来了吗？这的来，不知道是怎的？……”',
#  '“他中焦塞着中焦塞着：是中医用语',
#  '“他们一直从堂屋打到大门口……”益堂说',
#  '“他们不配我来写，”他说',
#  '“他们两个人就像一个人',
#  '“他们也还是一直从堂屋打到大门口……”',
#  '“他们俩订婚了不多几天，苏老太太来看家母，说了许多好话，说文纨这孩子脾气执拗，她自己劝过女儿没用，还说不要因为这事坏了苏家跟赵家两代交情',
#  '“他们大约也听到消息了',
#  '“他们忘却了纪念，纪念也忘却了他们！',
#  '“他们没有工夫',
#  '“他们没有来叫我',
#  '“他们没有说',
#  '“他们现在在哪里？”',
#  '“他们的老子要他们读这些，我是别人，无乎不可的',
#  '“他们知道我不娶的了',
#  '“他们西医叫猩红热，我们中医叫红斑痧',
#  '“他们要吃我，你一个人，原也无法可想',
#  '“他们说那一个叫作妲己的是狐狸精，只有两只脚变不成人样，便用布条子裹起来：真的？”',
#  '“他们还嚷什么‘新文化新文化’，‘化’到这样了，还不够？”他两眼盯着屋梁，尽自说下去',
#  '“他们都在社会的冷笑恶骂迫害倾陷里过了一生',
#  '“他们都被学校开除了，我不晓得',
#  '“他做了好些诗，又译过匈牙利和诗人彼得斐彼得斐（1823—1849）：通译裴多菲，匈牙利爱国诗人',
#  '“他停在那里，”大良的祖母走向前，指着说，“魏大人恭喜之后，我把正屋也租给他了',
#  '“他先前怕孩子们比孩子们见老子还怕，总是低声下气的',
#  '“他到了中大，不但不曾恢复他‘呐喊’的勇气，并且似乎在说‘在北方时受着种种迫压，种种刺激，到这里来没有压迫和刺激，也就无话可说了’',
#  '“他只说没有没有，我说你自己当面说去，他还要说，我说……”邹七嫂气喘吁吁的走着说',
#  '“他叫什么名字？”',
#  '“他叫卢那却尔斯基',
#  '“他可是很忙',
#  '“他哪里懂得你心里的事呢',
#  '“他喘不过气来，鼻翅子都扇着呢',
#  '“他在‘战时物资委员会’当处长，是新丈人替他谋的差使，这算得女儿嫁妆的一部分',
#  '“他如果能懂事，早就点了灯笼火把，寻了那孝女来了',
#  '“他姓什么？”',
#  '“他家里老妈子做的中菜',
#  '“他就是水生？第五个？都是生人，怕生也难怪的',
#  '“他就是胡闹，不想办一点正经事',
#  '“他是文学家？——他是哪一国人？”',
#  '“他本领比我大，仪表也很神气，将来一定得意',
#  '“他老人家也出来说话了么？……那是……',
#  '“他说：这些都另法办理……',
#  '“他这贱骨头打不怕，还要说可怜可怜哩',
#  '“他，犯了什么事啦？……”',
#  '“他？……他景况也很不如意……”母亲说着，便向房外看，“这些人又来了',
#  '“令弟仍然是忙？……”月生问',
#  '“以为自己抢人是好的，抢我就有点不乐意”，你以为这是变坏了的性质么？我想这是不好不坏，平平常常',
#  '“以后？——我不知道',
#  '“以眼还眼以牙还牙”：摩西的话，见《旧约·申命记》：“以眼还眼，以牙还牙，以手还手，以脚还脚',
#  '“以罗伊，以罗伊，拉马撒巴各大尼？！”〔翻出来，就是：我的上帝，你为甚么离弃我？！〕',
#  '“价钱决不会比别家出得少！”秀才说',
#  '“伊和希珂先，没有了，虾蟆的儿子',
#  '“传进来！”',
#  '“似战，似和，似守',
#  '“但也比敲碎宋国的所有饭碗好',
#  '“但你为什么给我去报仇的呢？你认识我的父亲么？”',
#  '“但你自己，又怎么办呢？”他反而问',
#  '“但她只知道一半',
#  '“但您究竟是他的先生呵！”',
#  '“但愿如此',
#  '“但是你为什么飞回来的呢？”',
#  '“但是，——不知道是怎么死的？”',
#  '“但是，老乡，你一行义，可真几乎把我的饭碗敲碎了！”公输般碰了一个钉子之后，改口说，但也大约很有了一些酒意：他其实是不会喝酒的',
#  '“何妨做志愿军呢？”',
#  '“何必推举呢？自然是主张发电的人罗～～',
#  '“何必跟她计较？我只觉得她可笑',
#  '“作善降祥”的古训，六朝人本已有些怀疑了，他们作墓志，竟会说“积善不报，终自欺人”的话',
#  '“你——你这个浑蛋！”苏小姐用中文骂他，声音似乎微颤',
#  '“你‘有法解释’，先对我表姐去讲',
#  '“你一向好么？还是忙？”',
#  '“你一定来，一定！我还得和老钵去接洽一回',
#  '“你不会要你的主人开一个窗的么？”',
#  '“你不是也恨着他么？”唐小姐狡猾地笑说',
#  '“你不是亲口对老钵说的么：你要谋一个教员做，去看看女学生？”',
#  '“你不是给上海的书铺子做过文章么？”',
#  '“你不知道，他们已经来革过了！”',
#  '“你不知道，我可是比先前更怕去访人了',
#  '“你不能用小一点的箭头的么？”',
#  '“你不能走得更远一点的么？！”',
#  '“你不要打！她跟你生的气，你别去自讨没趣',
#  '“你不要疑心我将骗取你的性命和宝贝',
#  '“你不要相信老钵的狗屁！”',
#  '“你不讨厌，可是全无用处',
#  '“你不错',
#  '“你为什么不回敬她？”',
#  '“你为什么要鼓动风潮呢，在学校里？”',
#  '“你么？你肯给我报仇么，义士？”',
#  '“你也知道出去了好半天么？反正好朋友在一起，吃喝玩乐，整夜不回来也由得你，我一个人死在旅馆里都没人来理会，”她说时嗓子哽咽起来，又回脸向里睡了',
#  '“你也许本来知道，”他接着说，“我曾经有一个小兄弟，是三岁上死掉的，就葬在这乡下',
#  '“你买，哈哈，哈哈！”',
#  '“你从实招来罢，免得吃苦',
#  '“你从此要改变你的优柔的性情，用这剑报仇去！”他的母亲说',
#  '“你以为我发了疯么？你以为我成了英雄或伟人了么？不，不的',
#  '“你们可看见过杀头么？”阿q说，“咳，好看',
#  '“你们可见太太吃了那箱里的药没有？”',
#  '“你们怎么又闹这些玩艺儿了？”我说',
#  '“你们的嘴里既然并无毒牙，何以偏要在额上贴起‘蝮蛇’两个大字，引乞丐来打杀？……”',
#  '“你们看见有什么向天上飞升的么？”他问',
#  '“你们要不改，自己也会吃尽',
#  '“你们说的是些什么呀？”楚王惊讶着问道',
#  '“你们都在家么？姚家，太太一个人不是向来不去的么？”',
#  '“你们都收好',
#  '“你休息一两天，去拜望亲戚本家一回，我们便可以走了',
#  '“你会不会有了孩子，所以身体这样不舒服？”“什么？胡说！“她脆快地回答——“假如真有了孩子，我不饶你！我不饶你！我不要孩子',
#  '“你借此还可以支持生活么？”我一面准备走，一面问',
#  '“你做得比文那首诗灵活',
#  '“你再没有可托的朋友了么？”我这时正是无法可想，连自己',
#  '“你别当面奉承我，我不相信你的话！”',
#  '“你别捉我的错字，也许她是个女人呢？我宁可跟女人在一起的，你们男人全不是好人，只要哄得我们让你们称了心，就不在乎了',
#  '“你前信说你教书很不如意',
#  '“你原来没有出过疹子？……”',
#  '“你原来这么大了，竟还没有出过疹子？”他遇到了什么奇迹似的，惊奇地问',
#  '“你去就是',
#  '“你又来什么事？”伊大吃一惊的说',
#  '“你反了，……你这……”',
#  '“你叫什么名字？”——第一句',
#  '“你可知道魏大人自从交运之后，人就和先前两样了，脸也抬高起来，气昂昂的',
#  '“你听我说，我教会计科一起送你四个月的薪水，你旅行的费用，不必向你老太爷去筹——”',
#  '“你吹？”他嘲笑似的微笑，但接着就坚定地说，“不能！不要你们',
#  '“你呀',
#  '“你回来了？”她先这样问',
#  '“你在做什么？怎么爹叫也不听见？”她谴责的说',
#  '“你在太原做什么呢？”我问',
#  '“你在我这里学了这许多年，还是这么老实，”老子笑了起来，“这真是性不能改，命不能换了',
#  '“你大约还记得我旧时的客厅罢，我们在城中初见和将别时候的客厅',
#  '“你好，八三！恭喜恭喜！……”',
#  '“你害的什么病，严重不严重？”鸿渐知道已经问得迟了',
#  '“你对辛楣的偏见太深',
#  '“你将以我为什么东西呢，你自己定就是，我都可以的',
#  '“你干什么？”但三角脸终于走上一步，诘问了',
#  '“你怎么会姓赵！——你哪里配姓赵！”',
#  '“你怎么会气？你只有称心',
#  '“你怎么会知道？那时你们都还是小把戏呢，单知道喝奶拉矢',
#  '“你怎么动手动脚……”尼姑满脸通红的说，一面赶快走',
#  '“你怎么学日本人的样子，身体既矮小，胡子又这样，……”一位国粹家兼爱国者发过一篇崇论宏议之后，就达到这一个结论',
#  '“你怎么知道呢？”七斤嫂有些着急，赶忙的问',
#  '“你怎么认识我？……”他极其惶骇地问',
#  '“你想想看，”伯夷知道他心里其实并不服气，便接着说，“我们是客人，因为西伯肯养老西伯肯养老：西伯即周文王姬昌',
#  '“你想，一个大学毕业生会那样天真幼稚么？‘方先生在哄我，是不是？’”——辛楣逼尖喉咙，自信模仿得维妙维肖——“我才不上她当呢！只有你这傻瓜！我告诉你，人不可以貌相',
#  '“你想，不坐龙庭了罢？”',
#  '“你或者愿意知道些我的消息，现在简直告诉你罢：我失败了',
#  '“你抄了这些有什么用？”有一夜，他翻着我那古碑的抄本，发了研究的质问了',
#  '“你改悔罢！”',
#  '“你放习，我决不做你的‘同情者’',
#  '“你放着罢，祥林嫂！”四婶慌忙大声说',
#  '“你教的是‘子曰诗云’么？”我觉得奇异，便问',
#  '“你明天下午来不来呀？”',
#  '“你昨天的牌风可好？”',
#  '“你昨天说，男人不把自己东西给女人，是什么意思呀？”',
#  '“你是什么意思？亏你还会再来见我们',
#  '“你是哪里人？”——第三句',
#  '“你是谁哪？怎么把我家的顶好的黑母鸡射死了？你的手怎的有这么闲哪？……”',
#  '“你查罢！”那青年立刻从床底下拖出自己的柳条箱来',
#  '“你没有上他的当罢！克莱登是好学校，他是这学校里开除的小职员，借着幌子向外国不知道的人骗钱，你真没有上当？唔，那最好',
#  '“你没法开！”',
#  '“你猜',
#  '“你现在也还是粉嫩粉嫩……”方头说',
#  '“你现在对于我的意见，就是我先前对于她的意见',
#  '“你的儿子一个也没有来？”',
#  '“你的客厅这么荒凉……近来客人不多了么？”',
#  '“你的烧完，使我惋惜',
#  '“你的脸色……',
#  '“你的醒来，使我欢喜',
#  '“你的骨头痒了么？”王胡也站起来，披上衣服说',
#  '“你看，多么糊涂！”道统大嚷道',
#  '“你看，还是为钱，”张沛君就慷慨地从破的躺椅上站起来，两眼在深眼眶里慈爱地闪烁',
#  '“你看，还说教书的要薪水是卑鄙哩',
#  '“你看：我牙齿还有吗？”他问',
#  '“你真是枉长白大！连母鸡也不认识，会当作鹁鸪！你究竟是谁哪？”',
#  '“你真是白来了一百多回',
#  '“你真爱到三闾大学去么？”鸿渐不由惊奇地问，“我佩服你的精神，我不如你',
#  '“你瞧，这是什么话？温柔敦厚的才是诗',
#  '“你知道么？猫是老虎的先生',
#  '“你知道有一个叫爱而的么？他写了一封长信给我，我没有看完',
#  '“你知道的',
#  '“你知道苦了罢？你改悔不改悔？”大约也不但正人君子，凡对我有些好意的人，也要问的',
#  '“你知道那首诗是谁做的？”她瞧方鸿渐瞪着眼，还不明白——“那首诗就是表姐做的，不是王乐恺的',
#  '“你肯原谅我，我不能饶恕我自己',
#  '“你自以为是‘人’，我却以为非也',
#  '“你自己做的事还不知道么？”',
#  '“你自己是不会记得的',
#  '“你自己，我可没有',
#  '“你要我老实说，好',
#  '“你要晓得红眼睛阿义是去盘盘底细的，他却和他攀谈了',
#  '“你说——只要猜疑的不是我',
#  '“你说中国不好',
#  '“你说就是',
#  '“你说得对',
#  '“你说甲生疮',
#  '“你说的对',
#  '“你说这首诗有蓝本也不冤枉',
#  '“你说，”马褂又冷笑了一声，“你是cp，还是cycp：英语communistparty的缩写，即共产党',
#  '“你还不是讲些行义么？”公输般道，“劳形苦心，扶危济急，是贱人的东西，大人们不取的',
#  '“你还不配……”这时候，又仿佛在他头上的是一种高尚的光容的癞头疮，并非平常的癞头疮了',
#  '“你还以为养大了她，其实正是害苦了她，倒不如小时候饿死的好！”',
#  '“你还是回去罢！倘不，你的伯伯会打断你的骨头！灯么，我替你吹',
#  '“你还算运气的哩，”老子说，“没有遇着能干的主子',
#  '“你这人真蛮不讲理',
#  '“你这位阿叔真通气，”爱姑高兴地说，“我虽然不认识你这位阿叔是谁',
#  '“你这妈的！”木三低声说',
#  '“你这孩子有点不对了，拿这篇文章去看去，抄下来去看去',
#  '“你这活死尸的囚徒……”',
#  '“你这话为什么不跟曹元朗夫妇去讲？”',
#  '“你这话给我父亲听见，该说‘孺子可教’了',
#  '“你那时之前，早知道我是谁么？”',
#  '“你！”我诧异地看定他的眼睛，说，“你莫非真正糊涂了？你看我这模样，还要看什么明板？……”',
#  '“使我委屈一世的就是你！”女的说',
#  '“侠”字渐消，强盗起了，但也是侠之流，他们的旗帜是“替天行道”',
#  '“俗怖婴儿曰：麻胡来！不知其源者，以为多髯之神而验刺者，非也',
#  '“信么？”靖甫问',
#  '“倒楣！”他尽量地大叫了一声，出出闷气',
#  '“倒高兴……',
#  '“假使这封信去了效果很好，我一定把稿子抄给你看',
#  '“假如一间铁屋子，是绝无窗户而万难破毁的，里面有许多熟睡的人们，不久都要闷死了，然而是从昏睡入死灭，并不感到就死的悲哀',
#  '“假洋鬼子不准我！”',
#  '“偏是谋生忙，便偏是多碰到些无聊事，白费工夫！”他将两腿在马肚子上一磕，催它快走，但马却只将后半身一扭，照旧地慢腾腾',
#  '“偏爱这不干净花，是糊涂孩子！”',
#  '“做点小工作”，指翻译《小约翰》',
#  '“健全的精神，宿于健全的身体之中”“健全的精神，宿于健全的身体之中”：西方古格言，见罗马讽刺诗人朱味那尔的《讽刺诗》第十篇',
#  '“像一个乞丐',
#  '“像你们的弟兄，那里有呢',
#  '“儒者，柔也”，当然不会危险的',
#  '“儿”读若“倪”，倒是古音罢',
#  '“儿呀！”',
#  '“先不管它',
#  '“先去吃两帖',
#  '“先坐船，……”',
#  '“先帝爷，在白帝城……”他一听到这低微高兴的吟声，便失望，愤怒，几乎要奔上去叱骂他',
#  '“先生',
#  '“先生什么时候回来呢？”耕柱子在后面叫喊道',
#  '“先生今天好像不大高兴，”庚桑楚看老子坐定了，才站在旁边，垂着手，说，“话说的很少……”',
#  '“先生今天好像很高兴，”庚桑楚看老子坐定了，才站在旁边，垂着手，说',
#  '“先生到楚国去？”',
#  '“先生在城圈边溜溜？”关尹喜问',
#  '“先生的意思以为这事情怎样呢？”这不识教员在招呼之后，看住了我的眼睛问',
#  '“先生的意思是说：硬的早掉，软的却在吗？”',
#  '“先生的聘书，我方才已经托辛楣带去了',
#  '“先生！”他悲哀地说，眼泪联成一线，就从眼角上直流下来',
#  '“先生！”他流着眼泪说，“你知道的',
#  '“先生！你干什么？”他大惊地说',
#  '“先生！我这样是敷衍不下去的',
#  '“先生，‘怪哉’这虫，是怎么一回事？……”我上了生书，将要退下来的时候，赶忙问',
#  '“先生，他发烧……',
#  '“先生，你的中国话说得真好',
#  '“先生，又有一个你的同乡来告帮了……这人可是有些古怪……”门丁轻轻的说',
#  '“先生，孔丘又来了！”他的学生庚桑楚，不耐烦似的走进来，轻轻的说',
#  '“先生，孔丘来了哩！”他的学生庚桑楚，诧异似的走进来，轻轻的说',
#  '“先生，您好吗？”孔子极恭敬的行着礼，一面说',
#  '“先生，我住的只是一间破小屋，又湿，又阴，满是臭虫，睡下去就咬得真可以',
#  '“先生，是做十多天的干粮罢？”他问',
#  '“先生，这病看来很不轻了，用药怕还得重一点罢',
#  '“克来登大学',
#  '“全部，或全无”，是他所信奉的一句格言',
#  '“公理”实在是不容易谈，不但在一个维持会上，就要自相矛盾，有时竟至于会用了“道义”上之手，自批“公理”上之脸的嘴巴',
#  '“公输子的意思，”墨子旋转身去，回答道，“不过想杀掉我，以为杀掉我，宋就没有人守，可以攻了',
#  '“六顺生了儿子，我想第二个就可以过继给他',
#  '“共产党不妨碍做诗，但于觉得自己是大作家的事却有妨碍',
#  '“其实，这本已可以不必再迁，只要平了土，卖掉棺材，就此完事了的',
#  '“养回了力气，再来罢',
#  '“再亮些”？不要骗人罢！你们的眼睛在哪里呢？',
#  '“况且，”老臣们向太监说，“大王的后枕骨是这么尖的么？”',
#  '“凭票付英洋英洋：即“鹰洋”，墨西哥银元，币面图案为一鹰（墨西哥国徽）',
#  '“凭票付英洋贰百元正',
#  '“出去了罢！”大良们的祖母，那三角眼的胖女人，从对面的窗口探出她花白的头来了，也大声说，不耐烦似的',
#  '“出去！”',
#  '“分好几等呢',
#  '“列传”么，这一篇并非和许多阔人排在“正史”“正史”：封建时代由官方撰修或认可的史书',
#  '“刚出屉的包子咧！荷阿，热的……',
#  '“刚才，四老爷和谁生气呢？”我问',
#  '“别人”，指陈西滢等',
#  '“别传”呢，阿q实在未曾有大总统上谕宣付国史馆立“本传”宣付国史馆立“本传”：旧时效忠于统治阶级的重要人物或所谓名人，死后由政府明令褒扬，令文末常有“宣付国史馆立传”的话',
#  '“别后共得三信，没有复',
#  '“别客气，我求你明天来',
#  '“别的准备怎么样？”',
#  '“别胡说！人家听见了好意思么？我近来觉悟了，决不再爱大学出身的都市女人',
#  '“别胡闹',
#  '“到东京就要假装大脚，又何必带这东西呢？”',
#  '“刻的是谁呢？”',
#  '“前天',
#  '“割不正不食”，这是他老先生的古板规矩，但“食不厌精，脍不厌细”的条令却有些稀奇',
#  '“劈柴，……”',
#  '“劈柴，都用完了，今天买了些',
#  '“勿用惊叹符号，这是足以亡国的',
#  '“包好，包好！”康大叔瞥了小栓一眼，仍然回过脸，对众人说，“夏三爷真是乖角儿，要是他不先告官，连他满门抄斩',
#  '“包好，包好！这样的趁热吃下',
#  '“北京却连蛙鸣也没有……”他又叹息说',
#  '“北方有人侮辱了我，”墨子很沉静的说',
#  '“医头痛最好是打打盹',
#  '“医者，意也',
#  '“千金之子坐不垂堂”：语见《史记·袁盎传》',
#  '“单四嫂子，孩子怎了？——看过先生了么？”',
#  '“即以其人之道，反诸其人之身……',
#  '“原来你也是这个道理！”方鸿渐和唐小姐亲密地笑着，两人已成了患难之交',
#  '“原来你家小栓碰到了这样的好运气了',
#  '“原来有保险灯在这里！”他们并不怕',
#  '“去拿你的书来',
#  '“去看一看罢',
#  '“去！”我一得警报，便走出公园，跳上车，径奔衙门去',
#  '“又是一位宝贝！跟那诗人做朋友的，没有好货',
#  '“又，剥皮者，从头至尻，一缕裂之，张于前，如鸟展翅，率逾日始绝',
#  '“友邦”要我们人民身受宰割，寂然无声，略有“越轨”，便加屠戮',
#  '“友邦人士”，从此可以不必“惊诧莫名”，只请放心来瓜分就是了',
#  '“双喜进门”的预言没有效验',
#  '“双喜，你们这班小鬼，昨天偷了我的豆了罢？又不肯好好的摘，踏坏了不少',
#  '“反正你对谁的话都听，尤其赵辛楣的话比圣旨都灵，就是我的话不听',
#  '“反正分付花店送就是了，管它什么花',
#  '“反正没好活说，逃不了那几句老套儿',
#  '“发不及了，领不出了，银行已经关了门，得等初八',
#  '“发了疯了',
#  '“发扬国光”是报道这些消息时的用语',
#  '“发财发财，你是——在……”',
#  '“发财？自然',
#  '“口”有“黑口”“白口”的分别：折缝上下端有黑线的叫做“黑口”，没有黑线的叫做“白口”',
#  '“古已有之”，“于今为烈”，我近来很有些怕敢看它了',
#  '“只在傻女人前面，是不是？”',
#  '“只要你给我两件东西',
#  '“只要有木片，现在就可以试一试',
#  '“只这一月里，煤油已经涨价两次了……”他旋好了灯头，慢慢地说',
#  '“叫呀！快叫呀！”她催促说',
#  '“叫呀，你父亲要断气了',
#  '“可不是么……”聪明人也代为高兴似的回答他',
#  '“可不是么！”他高兴了',
#  '“可以',
#  '“可以医么？”他愁苦地问',
#  '“可以可以，”墨子也诚恳的说，“我其实也并非爱穿破衣服的……只因为实在没有工夫换……”',
#  '“可以可以，那自然',
#  '“可以抄一点',
#  '“可以，”他说',
#  '“可恶！”四叔说',
#  '“可恶！然而……',
#  '“可惜他只有一个伯父……”阔亭立刻颓唐了',
#  '“可惜内中也有几个想学学做诗，那可是不行的',
#  '“可是上月领来的一成半都完了……昨天的米，也还是好容易才赊来的呢',
#  '“可是不送来又怎么好呢……哦，昨夜忘记说了，孩子们说那学费，学校里已经催过好几次了，说是倘若再不缴……”',
#  '“可是做工是昼夜无休息：清早担水晚烧饭，上午跑街夜磨面，晴洗衣裳雨张伞，冬烧汽炉夏打扇',
#  '“可是先生这么远来，有什么见教呢？”',
#  '“可是我以后只好做玩具了',
#  '“可是我听说去年年底施家送给慰老爷一桌酒席哩，八公公',
#  '“可是现在普通大学毕业亦得做论文',
#  '“可是还不及木匠的做车轮，”墨子看了一看，就放在席子上，说，“他削三寸的木头，就可以载重五十石',
#  '“可是魏大人的脾气也太古怪，”她忽然低声说，“他就不肯积蓄一点，水似的花钱',
#  '“可是，战败者常常得到旁人更大的同情——”唐小姐觉得这话会引起误会，红着脸——“我意思说，表姐也许是助弱小民族的',
#  '“可是，水生约我到他家玩去咧……”他睁着大的黑眼睛，痴痴的想',
#  '“可望得应科报，即令应科杀如月，剥皮示众',
#  '“吁……”他很长的嘘一口气，先斥退了脊梁上的针，仍然想，“幸福的家庭的房子要宽绰',
#  '“吁！……”伊吐出最后的呼吸来',
#  ...]

# %%
class Data(object):
    def __init__(self):
        self.data = dict()
    
    def add(self, pinYin, ciZu):
        if pinYin not in self.data:
            self.data[pinYin] = [{ciZu}, 1]
        else:
            self.data[pinYin][0].add(ciZu)
            self.data[pinYin][1] += 1
            
    def mk_dataframe(self):
        df = pd.DataFrame()
        df['tmp'] = self.data.values()
        df['candidates'] = df['tmp'].map(lambda e: e[0])
        df['freq'] = df['tmp'].map(lambda e: e[1])
        df['pinYin'] = self.data.keys()
        df = df[['pinYin', 'candidates', 'freq']]
        self.df = df.sort_values('freq', ascending=False)
        return df

    def query(self, pinYin):
        return self.df[self.df['pinYin'].str.startswith(pinYin)]

# %%
data = Data()

for string in tqdm(contents):
    ciZu = sorted(set([e.strip() for e in jieba.cut(string, cut_all=True)]))
    for c in ciZu:
        pinYin = ''.join(lazy_pinyin(c))
        data.add(pinYin, c)
        
data.mk_dataframe()
data.df
# Out:
#   0%|          | 0/25239 [00:00<?, ?it/s]
#              pinYin                                         candidates   freq
# 5                 ，                                                {，}  19525
# 34               de                                          {的, 得, 德}  15499
# 27              shi  {时, 式, 市, 噬, 师, 事, 失, 仕, 拾, 蚀, 栻, 轼, 施, 狮, 适, ...   8337
# 21               le                                          {乐, 了, 肋}   7859
# 43               ta                        {塔, 牠, 闼, 她, 它, 踏, 他, 塌, 榻}   6145
# ...             ...                                                ...    ...
# 22402      fangshen                                               {防身}      1
# 3690          eduzi                                              {饿肚子}      1
# 10398  quzhuchujing                                             {驱逐出境}      1
# 22406       henzang                                               {很脏}      1
# 15702        meizuo                                               {美作}      1
#
# [31404 rows x 3 columns]

# %%
data.query('qing')
# Out:
#               pinYin                               candidates  freq
# 554             qing  {庆, 请, 倾, 清, 轻, 擎, 晴, 情, 磬, 檠, 卿, 青, 顷}   469
# 224         qingnian                                     {青年}   249
# 4358        qingxing                             {清醒, 庆幸, 情形}    93
# 1063         qingchu                                 {清初, 清楚}    61
# 3173        qingqing                         {卿卿, 清清, 青青, 轻轻}    48
# ...              ...                                      ...   ...
# 10632      qingshizu                                    {清世祖}     1
# 14764        qingban                                     {清版}     1
# 3769   qingmiedixiao                                   {轻蔑地笑}     1
# 22134         qingqi                                     {轻气}     1
# 22149    qingnianhui                                    {青年会}     1
#
# [192 rows x 3 columns]
